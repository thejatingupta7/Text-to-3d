# %%
import requests
import json
from openai import OpenAI
import os

# Setup Azure OpenAI API
token = "ghp_P6Ic"
endpoint = "https://models.inference.ai.azure.com"
model_name = "gpt-4o"


client = OpenAI(
    base_url=endpoint,
    api_key=token,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Generate a 3js code for a 3d model, code only, no expalnation",
        },
        {
            "role": "user",
            "content": "Create a simple living room with a sofa, coffee table, and a TV stand",
        }
    ],
    temperature=0.85,
    top_p=1.0,
    max_tokens=4000,
    model=model_name,
)
import re
print(response.choices[0].message.content)
pattern = r"```(javascript|html|code)\s([\s\S]*?)```"
generated_content = re.search(pattern, response.choices[0].message.content).group(1).strip()
print(generated_content)
# Out:
# ```javascript
# // Import Three.js
# import * as THREE from 'three';
#
# // Set up the scene, camera, and renderer
# const scene = new THREE.Scene();
# const camera = new THREE.PerspectiveCamera(75, window.innerWidth / window.innerHeight, 0.1, 1000);
# const renderer = new THREE.WebGLRenderer();
# renderer.setSize(window.innerWidth, window.innerHeight);
# document.body.appendChild(renderer.domElement);
#
# // Add ambient light
# const ambientLight = new THREE.AmbientLight(0xffffff, 0.6);
# scene.add(ambientLight);
#
# // Add a directional light
# const directionalLight = new THREE.DirectionalLight(0xffffff, 0.8);
# directionalLight.position.set(5, 10, 7);
# scene.add(directionalLight);
#
# // Floor
# const floorGeometry = new THREE.PlaneGeometry(15, 15);
# const floorMaterial = new THREE.MeshStandardMaterial({ color: 0x8e8e8e });
# const floor = new THREE.Mesh(floorGeometry, floorMaterial);
# floor.rotation.x = -Math.PI / 2;
# scene.add(floor);
#
# // Sofa
# ...

# %%
n = """javascript```// Import Three.js
import * as THREE from 'three';

// Scene, Camera, Renderer
const scene = new THREE.Scene();
const camera = new THREE.PerspectiveCamera(75, window.innerWidth / window.innerHeight, 0.1, 1000);
const renderer = new THREE.WebGLRenderer();
renderer.setSize(window.innerWidth, window.innerHeight);
document.body.appendChild(renderer.domElement);

```"""

pattern = r"```(javascript|html|code)\s([\s\S]*?)```"
generated_content = re.search(pattern, response.choices[0].message.content).group(2).strip()
print(generated_content)
# Out:
# // Import Three.js
# import * as THREE from 'three';
#
# // Set up the scene, camera, and renderer
# const scene = new THREE.Scene();
# const camera = new THREE.PerspectiveCamera(75, window.innerWidth / window.innerHeight, 0.1, 1000);
# const renderer = new THREE.WebGLRenderer();
# renderer.setSize(window.innerWidth, window.innerHeight);
# document.body.appendChild(renderer.domElement);
#
# // Add ambient light
# const ambientLight = new THREE.AmbientLight(0xffffff, 0.6);
# scene.add(ambientLight);
#
# // Add a directional light
# const directionalLight = new THREE.DirectionalLight(0xffffff, 0.8);
# directionalLight.position.set(5, 10, 7);
# scene.add(directionalLight);
#
# // Floor
# const floorGeometry = new THREE.PlaneGeometry(15, 15);
# const floorMaterial = new THREE.MeshStandardMaterial({ color: 0x8e8e8e });
# const floor = new THREE.Mesh(floorGeometry, floorMaterial);
# floor.rotation.x = -Math.PI / 2;
# scene.add(floor);
#
# // Sofa
# ...

# %%
import requests

# Replace with your API key
api_key = "tsk_5vpqyo-YhMgQYmT_jHBv24wiTrj4eUO89TnbbYDTiMQ"

# Set the endpoint URL
url = "https://api.tripo3d.ai/v2/openapi/task"

# Define the headers
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# Define the data payload
data = {
    "type": "text_to_model",
    "prompt": "a small cat",  # Replace with your desired text
    "model_version": "v2.5-20250123"  # Optional, default version used if not specified
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)

# Print the response JSON
print(response.json())
# Out:
# {'code': 0, 'data': {'task_id': '4cbf8840-67c8-47c1-b64b-0def910b4bb4'}}

# %%
# Print the model details from the response
print(response.json())
# Out:
# {'code': 0, 'data': {'task_id': '0d70e238-1c35-48fa-b853-844209c2c814'}}
